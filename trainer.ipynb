# %% [markdown]
# # Activate GPU and Install Dependencies

# %%
import warnings,logging

warnings.simplefilter('ignore')
logging.disable(logging.WARNING)

# %%
# !apt-get install -qq git-lfs

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# # Preprocess data

# %%
import pandas as pd

train_df=pd.read_csv('data/train.csv')
test_df=pd.read_csv('data/test.csv')

len(train_df), len(test_df)
# Out:
# (21156, 2000)

# %%
train_df.describe(include='all').T
# Out:
#         Input         label
# count   21156  21156.000000
# unique  19817           NaN
# top      Zo'r           NaN
# freq      149           NaN
# mean      NaN      0.514842
# std       NaN      0.499791
# min       NaN      0.000000
# 25%       NaN      0.000000
# 50%       NaN      1.000000
# 75%       NaN      1.000000
# max       NaN      1.000000

# %%
from transformers import AutoTokenizer
tokz = AutoTokenizer.from_pretrained("rifkat/uztext-3Gb-BPE-Roberta")
# Out:
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/941k [00:00<?, ?B/s]

# %%
from datasets import Dataset

train_ds = Dataset.from_pandas(train_df)
test_ds = Dataset.from_pandas(test_df)

# %%
def preprocess_function(examples):
    return tokz(examples["Input"], truncation=True, padding=True)

tokenized_train = train_ds.map(preprocess_function, batched=True, load_from_cache_file=False, remove_columns='Input')
tokenized_test = test_ds.map(preprocess_function, batched=True, load_from_cache_file=False, remove_columns='Input')

columns_to_return = ['input_ids', 'label', 'attention_mask']
tokenized_train.set_format(type='torch', columns=columns_to_return)
# Out:
#   0%|          | 0/22 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer=tokz)

# %% [markdown]
# # Training the model

# %%
from transformers import AutoModelForSequenceClassification
model = AutoModelForSequenceClassification.from_pretrained("rifkat/uztext-3Gb-BPE-Roberta", num_labels=2)
# Out:
# Downloading:   0%|          | 0.00/319M [00:00<?, ?B/s]

# %%
import numpy as np
from datasets import load_metric
 
def compute_metrics(eval_pred):
    #load_precision=load_metric('precision')
    #load_recall=load_metric('recall')
    #load_f1 = load_metric("f1")
    load_accuracy = load_metric("accuracy")
  
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    #precision = load_precision.compute(predictions=predictions, references=labels)["precision"]
    #recall = load_recall.compute(predictions=predictions, references=labels)["recall"]
    #f1 = load_f1.compute(predictions=predictions, references=labels)["f1"]
    accuracy = load_accuracy.compute(predictions=predictions, references=labels)["accuracy"]
    # "Precision": precision, "Recall": recall, "F1": f1, 
    return {"Accuracy": accuracy}

# %%
dds = tokenized_train.train_test_split(0.10)
dds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 19040
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 2116
#     })
# })

# %%
from transformers import TrainingArguments, Trainer
 
repo_name = "uzroberta-finetuned-sa"
 
training_args = TrainingArguments(
    output_dir=repo_name,
    learning_rate=2e-5,
    warmup_ratio=0.1,
    lr_scheduler_type='cosine',
    fp16=True,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    num_train_epochs=6,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    report_to='none'
)

trainer = Trainer(
   model=model,
   args=training_args,
   train_dataset=dds['train'],
   eval_dataset=dds['test'],
   tokenizer=tokz,
   data_collator=data_collator,
   compute_metrics=compute_metrics,
)

# %%
trainer.train();
# Out:
#     <div>
#
#       <progress value='3501' max='7140' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3501/7140 29:55 < 31:07, 1.95 it/s, Epoch 2.94/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.341600</td>
#       <td>0.283263</td>
#       <td>0.889414</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.252200</td>
#       <td>0.273155</td>
#       <td>0.898393</td>
#     </tr>
#   </tbody>
# </table><p>
# Downloading builder script:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 122] Disk quota exceeded
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 trainer.train()
#
# File /usr/local/lib/python3.9/dist-packages/transformers/trainer.py:1409, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1404     self.model_wrapped = self.model
#    1406 inner_training_loop = find_executable_batch_size(
#    1407     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1408 )
# -> 1409 return inner_training_loop(
#    1410     args=args,
#    1411     resume_from_checkpoint=resume_from_checkpoint,
#    1412     trial=trial,
#    1413     ignore_keys_for_eval=ignore_keys_for_eval,
#    1414 )
#
# File /usr/local/lib/python3.9/dist-packages/transformers/trainer.py:1728, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1725     self.state.epoch = epoch + (step + 1) / steps_in_epoch
#    1726     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 1728     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1729 else:
#    1730     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File /usr/local/lib/python3.9/dist-packages/transformers/trainer.py:1916, in Trainer._maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1913     self._report_to_hp_search(trial, epoch, metrics)
#    1915 if self.control.should_save:
# -> 1916     self._save_checkpoint(model, trial, metrics=metrics)
#    1917     self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#
# File /usr/local/lib/python3.9/dist-packages/transformers/trainer.py:1988, in Trainer._save_checkpoint(self, model, trial, metrics)
#    1985     self.store_flos()
#    1987 output_dir = os.path.join(run_dir, checkpoint_folder)
# -> 1988 self.save_model(output_dir, _internal_call=True)
#    1989 if self.deepspeed:
#    1990     # under zero3 model file itself doesn't get saved since it's bogus! Unless deepspeed
#    1991     # config `stage3_gather_16bit_weights_on_model_save` is True
#    1992     self.deepspeed.save_checkpoint(output_dir)
#
# File /usr/local/lib/python3.9/dist-packages/transformers/trainer.py:2465, in Trainer.save_model(self, output_dir, _internal_call)
#    2462             self.deepspeed.save_checkpoint(output_dir)
#    2464 elif self.args.should_save:
# -> 2465     self._save(output_dir)
#    2467 # Push to the Hub when `save_model` is called by the user.
#    2468 if self.args.push_to_hub and not _internal_call:
#
# File /usr/local/lib/python3.9/dist-packages/transformers/trainer.py:2517, in Trainer._save(self, output_dir, state_dict)
#    2515         torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    2516 else:
# -> 2517     self.model.save_pretrained(output_dir, state_dict=state_dict)
#    2518 if self.tokenizer is not None:
#    2519     self.tokenizer.save_pretrained(output_dir)
#
# File /usr/local/lib/python3.9/dist-packages/transformers/modeling_utils.py:1627, in PreTrainedModel.save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, **kwargs)
#    1625 # Save the config
#    1626 if is_main_process:
# -> 1627     model_to_save.config.save_pretrained(save_directory)
#    1629 # Save the model
#    1630 if state_dict is None:
#
# File /usr/local/lib/python3.9/dist-packages/transformers/configuration_utils.py:445, in PretrainedConfig.save_pretrained(self, save_directory, push_to_hub, **kwargs)
#     442 # If we save using the predefined names, we can load using `from_pretrained`
#     443 output_config_file = os.path.join(save_directory, CONFIG_NAME)
# --> 445 self.to_json_file(output_config_file, use_diff=True)
#     446 logger.info(f"Configuration saved in {output_config_file}")
#     448 if push_to_hub:
#
# File /usr/local/lib/python3.9/dist-packages/transformers/configuration_utils.py:824, in PretrainedConfig.to_json_file(self, json_file_path, use_diff)
#     813 """
#     814 Save this instance to a JSON file.
#     815
#    (...)
#     821         is serialized to JSON file.
#     822 """
#     823 with open(json_file_path, "w", encoding="utf-8") as writer:
# --> 824     writer.write(self.to_json_string(use_diff=use_diff))
#
# OSError: [Errno 122] Disk quota exceeded

# %%
trainer.evaluate()

# %%
trainer.save()

# %% [markdown]
# # Analyzing new data with the model

# %%
trainer.push_to_hub()

# %%
from transformers import pipeline
 
sentiment_model = pipeline(model="murodbek/uzroberta-sentiment-analysis")
p = sentiment_model(["Yomon emas", "Yaxshimas"])
# Out:
# Downloading:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/786 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/318M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/941k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.02M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/957 [00:00<?, ?B/s]

# %%
test_df['preds'] = -1
for i in range(len(test_df)):
    test_df['preds'][i]=sentiment_model(test_df['Input'][i])[0]['label']

# %%
((test_df['preds']=='LABEL_1')==test_df['label']).mean()
# Out:
# 0.9655
